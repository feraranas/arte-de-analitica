# %% [markdown]
# # Python

# %%
# Busca el archivo avocado.csv descargado desde el repositorio.
# Abre el archivo en excel y observa su contenido.
# Abre el archivo con un editor de texto (gEdit, Notepad, Notepad++) o desde algún IDE (Xcode, Visual Studio Code).
# Observa cómo se separan las columnas (variables) y las filas (objetos).
# Utilizando los comandos open, close, read, readline, readlines, rstrip y split, mostrados por tu profesor, crea una función de Python que pueda leer los datos. Estos datos se guardarán en una matriz, que es lo que debe regresar la función.

from collections import Counter
import csv
import math

# DATOS GUARDADOS EN MATRIZ
def creaMatriz(nombre_archivo):
    with open(nombre_archivo, newline='') as archivo_csv:
        reader = csv.reader(archivo_csv)
        data = list(reader)
    return data

# %%
# EJERCICIO 1 
'''
¿Cuántos objetos hay?
'''
id=0
with open('avocado.csv', newline='') as File:  
    reader = csv.reader(File)
    for row in reader:
        id=id+1     
    print("Cantidad de objetos = ", id)
# Out:
# Cantidad de objetos =  18250

# %%
# EJERCICIO 2
'''
¿Cuál es el valor de la variable 2 del objeto 15?
'''
matriz = creaMatriz('avocado.csv')
print("Valor de la variable 2 del objeto 15", float(matriz[16][2]))
# Out:
# Valor de la variable 2 del objeto 15 1.28

# %%
# EJERCICIO 3
'''
¿Cuál es el mínimo y máximo de la variable 3?
'''
def accederDatos(matriz, ncol):
    columna = []
    for i in range(1, len(matriz)):
        if not matriz[i][ncol]:
            dato = 0
        else:
            dato = float(matriz[i][ncol])
        columna.append(dato)
    return columna

# %%
matriz = creaMatriz('avocado.csv')
print("Maximo de la variable 3 = ", max(accederDatos(matriz,3)))
print("Minimo de la variable 3 = ", min(accederDatos(matriz,3)))
# Out:
# Maximo de la variable 3 =  62505646.52
# Minimo de la variable 3 =  84.56

# %% [markdown]
# # Pandas

# %%
#Importar Pandas
import pandas as pd

# %%
# Leer el archivo utilizando read_csv
data = pd.read_csv("avocado.csv")

# %%
# Obtener las primeras líneas utilizando head
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
# Obtener diferentes combinaciones de columnas y datos
data.loc[13:17, ['Date', 'Total Volume', 'type']]
# Out:
#           Date  Total Volume          type
# 13  2015-09-27     106803.39  conventional
# 14  2015-09-20      69759.01  conventional
# 15  2015-09-13      76111.27  conventional
# 16  2015-09-06      99172.96  conventional
# 17  2015-08-30     105693.84  conventional

# %%
# Últimos datos de la tabla
data.tail(5)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
# Datos obtenidos por la función describe
data.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
# ¿Cuántos objectos hay?
data.count()
# Out:
# Unnamed: 0      18249
# Date            18249
# AveragePrice    18249
# Total Volume    18249
# 4046            18249
# 4225            18249
# 4770            18249
# Total Bags      18249
# Small Bags      18249
# Large Bags      18249
# XLarge Bags     18249
# type            18249
# year            18249
# region          18249
# dtype: int64

# %%
# ¿Cuál es el valor de la variable 2 del objeto 15?
data.iloc[15, 2]
# Out:
# 1.28

# %%
# ¿Cuál es el mínimo y máximo de la variable 3?
data.iloc[:, 3].describe()
# Out:
# count    1.824900e+04
# mean     8.506440e+05
# std      3.453545e+06
# min      8.456000e+01
# 25%      1.083858e+04
# 50%      1.073768e+05
# 75%      4.329623e+05
# max      6.250565e+07
# Name: Total Volume, dtype: float64

# %% [markdown]
# # </br></br>Visualización de Datos

# %%
import seaborn as sb
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# Diagrama de Cajas (boxplot)

fig = plt.figure(figsize =(16, 7))
data.boxplot(grid=True, rot=45, fontsize=15)
# Out:
# <AxesSubplot:>

# %%
# Funcion histograma

histograma = data.hist(bins=5, xrot = 45, figsize=(10,15))

# %%
# Función correlacion
data.corr(method='pearson')
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.133008      0.014035  0.017628  0.019829
# AveragePrice   -0.133008      1.000000     -0.192752 -0.208317 -0.172928
# Total Volume    0.014035     -0.192752      1.000000  0.977863  0.974181
# 4046            0.017628     -0.208317      0.977863  1.000000  0.926110
# 4225            0.019829     -0.172928      0.974181  0.926110  1.000000
# 4770            0.041752     -0.179446      0.872202  0.833389  0.887855
# Total Bags     -0.002219     -0.177088      0.963047  0.920057  0.905787
# Small Bags      0.000347     -0.174730      0.967238  0.925280  0.916031
# Large Bags     -0.009196     -0.172940      0.880640  0.838645  0.810015
# XLarge Bags    -0.011546     -0.117592      0.747157  0.699377  0.688809
# year           -0.171667      0.093197      0.017193  0.003353 -0.009559
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
# Función heatmap
sb.heatmap(data[['AveragePrice', 
                 'Total Volume', 
                 '4046', '4225', 
                 '4770', 
                 'Total Bags', 
                 'Small Bags', 
                 'Large Bags', 
                 'XLarge Bags',
                 'year']], robust=True)
# Out:
# <AxesSubplot:>
