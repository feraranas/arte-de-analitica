# %% [markdown]
# # Actividad Evaluable 2

# %% [markdown]
# ## Obtencion de estadísticas descriptivas

# %% [markdown]
# # 1.

# %%
# Carga los datos usando tu lector de csv o con pandas.
import pandas as pd
data = pd.read_csv('covid19_tweets.csv')

# %% [markdown]
# # 2.

# %%
# Verifica la cantidad de datos que tienes, 
len(data)
# Out:
# 74436

# %%
# Verifca las variables que contiene cada vector de datos 
data.columns
# Out:
# Index(['user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'is_retweet'],
#       dtype='object')

# %%
# Identifica el tipo de variables
data.dtypes
# Out:
# user_name           object
# user_location       object
# user_description    object
# user_created        object
# user_followers       int64
# user_friends         int64
# user_favourites      int64
# user_verified         bool
# date                object
# text                object
# hashtags            object
# source              object
# is_retweet            bool
# dtype: object

# %% [markdown]
# # 3.

# %%
# Analiza las variables para saber qué representa cada una y en qué rangos se encuentran.
# Si la descripción del problema no te lo indica, utiliza el máximo y el mínimo para encontrarlo.
selected = data.groupby('user_name').count().sort_values(by='user_followers', ascending=False)
selected[1:15]
# Out:
#                                          user_location  user_description  \
# user_name
# covidnews.ch                                       239               239
# Coronavirus Updates                                  0               181
# Open Letters                                       177               177
# Hindustan Times                                    125               125
# IAM Platform                                       120               120
# Coronavirus Updates - Alexander Higgins              0               112
# Paperbirds_Coronavirus                               0               106
# OTV                                                100               100
# Blood Donors India                                  99                99
# Covid Data                                           0                92
# ABS-CBN News                                        91                91
# Musafir Namah                                       88                88
# ...

# %% [markdown]
# # 4.

# %%
# Basándose en la media, mediana y desviación estándar de cada variable, 
#¿Qué conclusiones puedes entregar de los datos?
data.describe()
# Out:
#        user_followers   user_friends  user_favourites
# count    7.443600e+04   74436.000000     7.443600e+04
# mean     1.059513e+05    2154.721170     1.529747e+04
# std      8.222900e+05    9365.587474     4.668971e+04
# min      0.000000e+00       0.000000     0.000000e+00
# 25%      1.660000e+02     153.000000     2.200000e+02
# 50%      9.600000e+02     552.000000     1.927000e+03
# 75%      5.148000e+03    1780.250000     1.014800e+04
# max      1.389284e+07  497363.000000     2.047197e+06
